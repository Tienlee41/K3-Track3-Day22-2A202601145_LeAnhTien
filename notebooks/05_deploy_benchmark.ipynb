# %% [markdown]
# # NB5/NB6 — Optional deployment and benchmark
#
# Executed evidence notebook for the Day 22 DPO alignment lab.
# Interpreter: `D:\aia\K3-Track3-Day22-2A202601145_LeAnhTien\.venv\Scripts\python.exe`

# %%
import json
from pathlib import Path
gguf = Path('../gguf/lab22-dpo-Q4_K_M.gguf')
deploy_path = Path('../submission/deploy.json')
benchmark = json.loads(Path('../submission/benchmark.json').read_text(encoding='utf-8'))
hub_path = Path('../submission/huggingface.json')
print('GGUF:', gguf.exists(), round(gguf.stat().st_size / 1024**3, 3) if gguf.exists() else None, 'GiB')
print('llama.cpp smoke:', json.loads(deploy_path.read_text(encoding='utf-8')) if deploy_path.exists() else 'not run; optional')
print('benchmark scope:', benchmark['scope'])
print('benchmark summary:', benchmark['summary'])
print('Hugging Face bonus:', json.loads(hub_path.read_text(encoding='utf-8'))['repositories'] if hub_path.exists() else 'not submitted (Option A)')
print('benchmark screenshot:', Path('../submission/screenshots/06_benchmark_summary.png').exists())
# Out:
# GGUF: True 1.797 GiB
# llama.cpp smoke: {'llama_cpp_tag': 'b10566', 'gguf': 'gguf\\lab22-dpo-Q4_K_M.gguf', 'size_bytes': 1929902464, 'size_gb': 1.797, 'quantization': 'Q4_K_M', 'prompt': 'Viết một câu tiếng Việt giải thích học máy là gì.', 'response': 'Học máy là một lĩnh vực trong trí tuệ nhân tạo, trong đó máy tính được huấn luyện để học từ dữ liệu và tự cải thiện qua thời gian.', 'coherent_vietnamese': True, 'stdout_log': 'submission\\llama_smoke.stdout.txt'}
# benchmark scope: 2-item smoke subset per suite; not official leaderboard scores
# benchmark summary: {'sft': {'AlpacaEval-lite': 1.0, 'GSM8K-lite': 0.0, 'IFEval-lite': 0.0, 'MMLU-lite': 1.0}, 'dpo': {'AlpacaEval-lite': 1.0, 'GSM8K-lite': 0.0, 'IFEval-lite': 1.0, 'MMLU-lite': 1.0}}
# Hugging Face bonus: {'sft': 'https://huggingface.co/tiennn/day22-qwen25-3b-sft-mini', 'dpo': 'https://huggingface.co/tiennn/day22-qwen25-3b-dpo'}
# benchmark screenshot: True
